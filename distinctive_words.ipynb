# %%
import os
import csv
from scipy.stats import fisher_exact

# %%
metadata_fn = "./metadata.csv"

corpus_directory = "./books"

# %%
# Functions

# Take a filename, return some text
def file2text(filename):
    f=open(filename)
    text=f.read()
    f.close()
    return text

# Take a filename for some standard spreadsheet form, return a list of lists
def file2rows(filename,sep = ',',no_ufeff=True):
    rows = []
    with open(filename, newline='\n') as metadata:
        reader = csv.reader(metadata, delimiter=",", quotechar="\"")
        for row in reader:
            rows.append(row)
    if no_ufeff:
        rows[0][0] = rows[0][0].replace("\ufeff",'')
    return rows

# Take a directory, give back a list of the files in it
def dir2filelist(somedir,path=True):
    files = os.listdir(somedir)
    if path:
        files = [os.path.join(somedir,filename) for filename in files]
    return files

# Take a directory, list the files in it of a given type
def dir2files(directory,path=True,file_type = ".txt"):
    files = dir2filelist(directory,path)
    for i in files[:]:
        if not i.endswith(file_type):
            files.remove(i)
    return files

# Take a path, get back the filename alone
def get_shortname(somepath):
    sn = os.path.basename(os.path.normpath(somepath))
    return sn

# Take a messy word and give back a tidier version
def cleanword(w,lower=True,no_apostrophe=False):
    # Usually want to make lowercase, but might not with names
    if lower: 
        w=w.casefold()
    while w and not w[0].isalpha():
        w=w[1:]
    while w and not w[-1].isalpha():
        w=w[:-1]
    # all of this is if you want to get rid of apostrophe s's
    if no_apostrophe:
        if w.endswith("'s"):
            w=w[:-2]
        if w.endswith("’s"):
            w=w[:-2]
    return w

# Take some text and give back a list of words
def text2words(sometext,no_apostrophe=False,no_blank=True):
    words = sometext.split()
    words = [cleanword(w,no_apostrophe=no_apostrophe) for w in words]
    if no_blank:
        words = [i for i in words if i != '']
    return words

# Take a filename and give back a list of words
def file2words(filename,no_apostrophe=False,no_blank=True):
    ftw_text = file2text(filename)
    ftw_words = text2words(ftw_text,no_apostrophe=no_apostrophe,no_blank=no_blank)
    return ftw_words

# Take some raw MDW data for a given word and get back some refined MDW data
def get_fishers(someword,somecountdict,someratedict,obs_exp=True,alternative='greater'):
    r = someratedict[someword]
    wc = sum(somecountdict.values())
    a = somecountdict[someword]
    b = wc - a
    c = round(r*wc)
    d = wc-c
    p = fisher_exact([[a,b],[c,d]],alternative=alternative)[1]
    if obs_exp == True:
        if c != 0:
            oe = a/c
        else:
            oe = "Inf"
        p = (p,oe)
    return p

# Takes a list of lists and writes out a spreadsheet
def lol2file(somelol,filename,sep=","):
    with open(filename,'w') as output_file:
        writer = csv.writer(output_file, delimiter=",", quotechar="\"")
        for row in somelol:
            writer.writerow(row)
    print("Wrote the file " + filename)
    
# Take a file and make a list based on linebreaks
def file2list(filename):
    f=open(filename)
    text=f.read()
    olist = text.splitlines()
    return olist

# %%
# Read in your metadata file
metadata_rows = file2rows(metadata_fn)

# %%
# See the headers and the column numbers if you want
for n,i in enumerate(metadata_rows[0]):
    print(n,i)
# Out:
# 0 Author
# 1 Author Country of Origin
# 2 Modern Country of Origin
# 3 Author Lifespan
# 4 Title
# 5 Subtitle
# 6 Release Date
# 7 Publication Date
# 8 Subject
# 9 Language
# 10 Copyright Status
# 11 Download Link
# 12 Gutenberg Link

# %%
# Also specify which column has your filenames
title_column = 4

corpora = set()

file_corpora = {}

for row in metadata_rows[1:]:
    c = row[title_column]
    corpora.add(c)
    filename = f"{c}.txt"
    file_corpora[filename] = c
    
corpora = list(corpora)

# %%
# Get the counts for every word, by corpus and overall

files = dir2files(corpus_directory)

corpus_counts = {i:{} for i in corpora}
all_counts = {}
cull_counts = {}

for f in files:
    sn = get_shortname(f)
    print(sn)
    corpus = file_corpora[sn]
    words = file2words(f)
    for w in words:
        if w not in corpus_counts[corpus]:
            corpus_counts[corpus][w] = 0
        corpus_counts[corpus][w] += 1
        if w not in all_counts:
            all_counts[w] = 0
        all_counts[w] += 1
    for w in set(words):
        if w not in cull_counts:
            cull_counts[w] = 0
        cull_counts[w] += 1
        
        
rates = {}
total_wc = sum(all_counts.values())

for w,c in all_counts.items():
    rates[w] = c/total_wc
# Out:
# A Sentimental Journey Through France and Italy.txt
# Studies in the Psychology of Sex, Volume 4.txt
# The Backwash of War.txt
# The Decameron, Volume I.txt
# Studies in the Psychology of Sex, Volume 5.txt
# Corinne; Or, Italy. Volume 1 (of 2).txt
# Ulysses.txt
# Poems and Ballads (Third Series).txt
# The Satyricon — Complete.txt
# Lysistrata.txt
# Memoirs of Fanny Hill.txt
# The History of the Decline and Fall of the Roman Empire.txt
# Studies in the Psychology of Sex, Volume 6.txt
# Candide.txt
# Faust [part 1]. Translated Into English in the Original Metres.txt
# The Adventures of Sherlock Holmes.txt
# The Sorrows of Young Werther.txt
# Sinister Street, vol. 2.txt
# Studies in the Psychology of Sex, Volume 2.txt
# The Awakening, and Selected Short Stories.txt
# Adam Bede.txt
# The Golden Asse.txt
# The Fortunate Mistress (Parts 1 and 2).txt
# Studies in the Psychology of Sex, Volume 3.txt
# The Kama Sutra of Vatsyayana.txt
# In Praise of Folly.txt
# Sinister Street, vol. 1.txt
# Richard II.txt
# Principles of Political Economy.txt
# Women in Love.txt
# Studies in the Psychology of Sex, Volume 1.txt
# The Clouds.txt
# The Prince.txt
# First Footsteps in East Africa.txt
# On the Origin of Species By Means of Natural Selection.txt
# Areopagitica.txt
# The Writings of Thomas Paine — Volume 4 (1794-1796): The Age of Reason.txt
# Casanova's Homecoming.txt
# King Lear.txt
# The History of Don Quixote, Volume 2, Complete.txt
# Sister Carrie.txt
# The Shewing-up of Blanco Posnet.txt
# The "Genius".txt
# The Loom of Youth.txt
# A Mummer's Wife.txt
# Les Misérables.txt
# Madame Bovary.txt
# Paradise Lost.txt
# The Prose Writings of Heinrich Heine.txt
# Tess of the d'Urbervilles: A Pure Woman.txt
# Pascal's Pensées.txt
# Rosamund, Queen of the Lombards: A Tragedy.txt
# Sons and Lovers.txt
# The Scarlet Letter.txt
# Une Vie, a Piece of String and Other Stories.txt
# The Decameron, Volume II.txt
# The Writings of Thomas Paine — Volume 2 (1779-1792): The Rights of Man.txt
# A Mummer's Tale.txt
# Tartuffe; Or, The Hypocrite.txt
# Uncle Tom's Cabin.txt
# The Works of Christopher Marlowe, Vol. 3 (of 3).txt
# The History of Don Quixote, Volume 1, Complete.txt
# Poems & Ballads (Second Series).txt
# Voltaire's Philosophical Dictionary.txt
# Man and Superman: A Comedy and a Philosophy.txt
# Religio Medici, Hydriotaphia, and the Letter to a Friend.txt
# The Call of the Wild.txt
# The Works of Henry Fielding, vol. 12.txt
# Disputation of Doctor Martin Luther on the Power and Efficacy of Indulgences.txt
# An Essay Concerning Humane Understanding, Volume 1.txt
# The Bickerstaff-Partridge Papers.txt
# Essays of Michel de Montaigne — Complete.txt
# The Kreutzer Sonata and Other Stories.txt
# Gargantua and Pantagruel.txt
# Esther Waters.txt
# The Rainbow.txt
# An Essay Concerning Humane Understanding, Volume 2.txt
# The Communist Manifesto.txt
# Ghosts.txt
# Poems & Ballads (First Series).txt
# Susan Lenox: Her Fall and Rise.txt
# The History of the Devil, As Well Ancient as Modern: In Two Parts.txt
# Jurgen: A Comedy of Justice.txt
# Family Limitation.txt
# Dubliners.txt
# Gulliver's Travels into Several Remote Nations of the World.txt
# The Birds.txt
# The Advancement of Learning.txt
# A Tale of a Tub.txt
# Tales and Novels of J. de La Fontaine — Complete.txt
# Napoleon the Little.txt
# The Memoirs of Jacques Casanova de Seingalt, 1725-1798. Complete.txt
# The Critique of Practical Reason.txt
# The Dramas of Victor Hugo: Mary Tudor, Marion de Lorme, Esmeralda.txt
# History of Tom Jones, a Foundling.txt
# The Praise of Folly.txt
# Pamela, or Virtue Rewarded.txt
# Adventures of Huckleberry Finn.txt
# Émile; Or, Concerning Education; Extracts.txt
# The Delights of Wisdom Pertaining to Conjugial Love.txt
# The Child of Pleasure.txt
# Mademoiselle Fifi.txt
# Notre-Dame de Paris.txt
# Alice's Adventures in Wonderland.txt
# Salammbo.txt
# Jerusalem Delivered.txt
# A System of Logic, Ratiocinative and Inductive.txt
# The Chinese Classics — Volume 1: Confucian Analects.txt
# The Complete Poetical Works of Percy Bysshe Shelley — Volume 3.txt
# The Prose Works of Jonathan Swift, D.D. — Volume 06.txt
# The Sex Side of Life: An Explanation for Young People.txt
# The Complete Plays of Gilbert and Sullivan.txt
# The Odyssey.txt
# The Complete Poetical Works of Percy Bysshe Shelley — Volume 1.txt
# Dante. An essay. To which is added a translation of De Monarchia..txt
# Jude the Obscure.txt
# Three Weeks.txt
# The Commercial Restraints of Ireland.txt
# The Merchant of Venice.txt
# The Chinese Classics: with a translation, critical and exegetical notes, prolegomena and copious indexes.txt
# The Adventures of Tom Sawyer, Complete.txt
# The Analects of Confucius (from the Chinese Classics).txt
# Emile.txt
# The Temptation of St. Antony; Or, A Revelation of the Soul.txt
# The Jungle.txt
# The Robbers.txt
# Leaves of Grass.txt
# The Poetical Works of Elizabeth Barrett Browning, Volume 4.txt
# Mrs. Warren's Profession.txt

# %% [markdown]
# ### Make some decisions
# * Pick a cutoff (words must appear x times or we ignore them)
#  * A higher cutoff makes the process much faster
#  * You may also find infrequent words less interesting to analyze (although maybe not!)
# * Choose an alpha (.05 is standard)
# * Decide whether you want to exclude stopwords
# * Decide if you want to cull the words by setting a minimum number of documents in which they must appear.
#  * That is, set how many different documents must contin a word in order for it to appear in your results. The idea is to balance between removing things like names that appear in one text but not things like "whale" which could characterize a Melville corpus against Dickens.
#  * The higher you go, the more apt you are to exclude things like character names
#  * One consideration: If the number is greater than the number of documents in the smallest subcorpus, you'll lose words that characterize that corpus. E.g., there are only 4 Fitzgerald novels in our author corpus. If you set your min_docs > 4, you'll lose any words used only by Fitzgerald.
# * Adjust the headers on your output spreadsheet if you like

# %%
cutoff = 10
alpha = .05
exclude_stops = True
min_docs = 15

output_table = [['corpus','token_','count','p_value','obs/exp']]

# %%
if exclude_stops:
    stops = file2list('stopwords.txt')

true_cull = min(min_docs,len(files))
counts = {}
    
print('Calculating significance...')
for corpus,data in corpus_counts.items():
    print(f'Working on the {corpus} corpus...')
    for w,c in data.items():
        if c < cutoff:
            continue
        if cull_counts[w] < true_cull:
            continue
        if exclude_stops:
            if w in stops or len(w) == 1:
                continue
        p,oe = get_fishers(w,data,rates)
        if p < alpha:
            output_table.append([corpus,w,c,p,oe])
            if corpus in counts:
                counts[corpus] += 1
            else:
                counts[corpus] = 1
print('Complete!')
# Out:
# Calculating significance...
# Working on the King Lear corpus...
# Working on the The Writings of Thomas Paine — Volume 2 (1779-1792): The Rights of Man corpus...
# Working on the The Adventures of Sherlock Holmes corpus...
# Working on the The Satyricon — Complete corpus...
# Working on the Studies in the Psychology of Sex, Volume 2 corpus...
# Working on the The Complete Poetical Works of Percy Bysshe Shelley — Volume 3 corpus...
# Working on the Mademoiselle Fifi corpus...
# Working on the Adventures of Huckleberry Finn corpus...
# Working on the Memoirs of Fanny Hill corpus...
# Working on the The Complete Plays of Gilbert and Sullivan corpus...
# Working on the Studies in the Psychology of Sex, Volume 3 corpus...
# Working on the Emile corpus...
# Working on the The Prince corpus...
# Working on the Corinne; Or, Italy. Volume 1 (of 2) corpus...
# Working on the The Sex Side of Life: An Explanation for Young People corpus...
# Working on the The Decameron, Volume I corpus...
# Working on the Lysistrata corpus...
# Working on the Sister Carrie corpus...
# Working on the The Poetical Works of Elizabeth Barrett Browning, Volume 4 corpus...
# Working on the Studies in the Psychology of Sex, Volume 6 corpus...
# Working on the The Prose Writings of Heinrich Heine corpus...
# Working on the Une Vie, a Piece of String and Other Stories corpus...
# Working on the The Fortunate Mistress (Parts 1 and 2) corpus...
# Working on the Essays of Michel de Montaigne — Complete corpus...
# Working on the Jurgen: A Comedy of Justice corpus...
# Working on the Pamela, or Virtue Rewarded corpus...
# Working on the Poems & Ballads (Second Series) corpus...
# Working on the Casanova's Homecoming corpus...
# Working on the Sons and Lovers corpus...
# Working on the The Delights of Wisdom Pertaining to Conjugial Love corpus...
# Working on the The History of the Decline and Fall of the Roman Empire corpus...
# Working on the Ulysses corpus...
# Working on the The Chinese Classics: with a translation, critical and exegetical notes, prolegomena and copious indexes corpus...
# Working on the The Jungle corpus...
# Working on the Susan Lenox: Her Fall and Rise corpus...
# Working on the The Awakening, and Selected Short Stories corpus...
# Working on the Studies in the Psychology of Sex, Volume 1 corpus...
# Working on the The Robbers corpus...
# Working on the Napoleon the Little corpus...
# Working on the A Mummer's Tale corpus...
# Working on the The Advancement of Learning corpus...
# Working on the The Kama Sutra of Vatsyayana corpus...
# Working on the The Call of the Wild corpus...
# Working on the The Rainbow corpus...
# Working on the Richard II corpus...
# Working on the The Shewing-up of Blanco Posnet corpus...
# Working on the Les Misérables corpus...
# Working on the The Dramas of Victor Hugo: Mary Tudor, Marion de Lorme, Esmeralda corpus...
# Working on the Studies in the Psychology of Sex, Volume 5 corpus...
# Working on the First Footsteps in East Africa corpus...
# Working on the The Works of Henry Fielding, vol. 12 corpus...
# Working on the The History of the Devil, As Well Ancient as Modern: In Two Parts corpus...
# Working on the The Adventures of Tom Sawyer, Complete corpus...
# Working on the Tartuffe; Or, The Hypocrite corpus...
# Working on the Sinister Street, vol. 2 corpus...
# Working on the The Birds corpus...
# Working on the Gulliver's Travels into Several Remote Nations of the World corpus...
# Working on the A Mummer's Wife corpus...
# Working on the The History of Don Quixote, Volume 1, Complete corpus...
# Working on the Leaves of Grass corpus...
# Working on the Family Limitation corpus...
# Working on the The Writings of Thomas Paine — Volume 4 (1794-1796): The Age of Reason corpus...
# Working on the A Sentimental Journey Through France and Italy corpus...
# Working on the Sinister Street, vol. 1 corpus...
# Working on the Uncle Tom's Cabin corpus...
# Working on the The Golden Asse corpus...
# Working on the A Tale of a Tub corpus...
# Working on the The Bickerstaff-Partridge Papers corpus...
# Working on the An Essay Concerning Humane Understanding, Volume 1 corpus...
# Working on the A System of Logic, Ratiocinative and Inductive corpus...
# Working on the Three Weeks corpus...
# Working on the Paradise Lost corpus...
# Working on the The Analects of Confucius (from the Chinese Classics) corpus...
# Working on the Dubliners corpus...
# Working on the In Praise of Folly corpus...
# Working on the Tales and Novels of J. de La Fontaine — Complete corpus...
# Working on the Religio Medici, Hydriotaphia, and the Letter to a Friend corpus...
# Working on the Dante. An essay. To which is added a translation of De Monarchia. corpus...
# Working on the Jude the Obscure corpus...
# Working on the Disputation of Doctor Martin Luther on the Power and Efficacy of Indulgences corpus...
# Working on the On the Origin of Species By Means of Natural Selection corpus...
# Working on the Poems & Ballads (First Series) corpus...
# Working on the The Backwash of War corpus...
# Working on the The Scarlet Letter corpus...
# Working on the Poems and Ballads (Third Series) corpus...
# Working on the Esther Waters corpus...
# Working on the The Prose Works of Jonathan Swift, D.D. — Volume 06 corpus...
# Working on the Areopagitica corpus...
# Working on the Salammbo corpus...
# Working on the The Communist Manifesto corpus...
# Working on the Madame Bovary corpus...
# Working on the The Memoirs of Jacques Casanova de Seingalt, 1725-1798. Complete corpus...
# Working on the Adam Bede corpus...
# Working on the The Commercial Restraints of Ireland corpus...
# Working on the Studies in the Psychology of Sex, Volume 4 corpus...
# Working on the The Kreutzer Sonata and Other Stories corpus...
# Working on the The Clouds corpus...
# Working on the Faust [part 1]. Translated Into English in the Original Metres corpus...
# Working on the Pascal's Pensées corpus...
# Working on the Gargantua and Pantagruel corpus...
# Working on the Alice's Adventures in Wonderland corpus...
# Working on the Mrs. Warren's Profession corpus...
# Working on the The Temptation of St. Antony; Or, A Revelation of the Soul corpus...
# Working on the On the Origin of Species by Means of Natural Selection corpus...
# Working on the The Odyssey corpus...
# Working on the An Essay Concerning Humane Understanding, Volume 2 corpus...
# Working on the Rosamund, Queen of the Lombards: A Tragedy corpus...
# Working on the The Complete Poetical Works of Percy Bysshe Shelley — Volume 1 corpus...
# Working on the The History of Don Quixote, Volume 2, Complete corpus...
# Working on the History of Tom Jones, a Foundling corpus...
# Working on the The Works of Christopher Marlowe, Vol. 3 (of 3) corpus...
# Working on the The Critique of Practical Reason corpus...
# Working on the Man and Superman: A Comedy and a Philosophy corpus...
# Working on the The Decameron, Volume II corpus...
# Working on the The Loom of Youth corpus...
# Working on the Candide corpus...
# Working on the The "Genius" corpus...
# Working on the Principles of Political Economy corpus...
# Working on the The Sorrows of Young Werther corpus...
# Working on the Voltaire's Philosophical Dictionary corpus...
# Working on the Ghosts corpus...
# Working on the Émile; Or, Concerning Education; Extracts corpus...
# Working on the The Child of Pleasure corpus...
# Working on the Jerusalem Delivered corpus...
# Working on the The Merchant of Venice corpus...
# Working on the Women in Love corpus...
# Working on the The Chinese Classics — Volume 1: Confucian Analects corpus...
# Working on the Notre-Dame de Paris corpus...
# Working on the The Praise of Folly corpus...
# Working on the Tess of the d'Urbervilles: A Pure Woman corpus...
# Complete!

# %%
print(len(output_table))
print(counts)
with open("counts.csv", "w") as counts_file:
    writer = csv.writer(counts_file)
    for k,v in counts.items():
        writer.writerow([k,v])
# Out:
# 55465
# {'King Lear': 106, 'The Writings of Thomas Paine — Volume 2 (1779-1792): The Rights of Man': 471, 'The Adventures of Sherlock Holmes': 378, 'The Satyricon — Complete': 249, 'Studies in the Psychology of Sex, Volume 2': 740, 'The Complete Poetical Works of Percy Bysshe Shelley — Volume 3': 585, 'Mademoiselle Fifi': 66, 'Adventures of Huckleberry Finn': 435, 'Memoirs of Fanny Hill': 357, 'The Complete Plays of Gilbert and Sullivan': 594, 'Studies in the Psychology of Sex, Volume 3': 764, 'Emile': 901, 'The Prince': 260, 'Corinne; Or, Italy. Volume 1 (of 2)': 488, 'The Sex Side of Life: An Explanation for Young People': 1, 'The Decameron, Volume I': 521, 'Lysistrata': 64, 'Sister Carrie': 569, 'The Poetical Works of Elizabeth Barrett Browning, Volume 4': 243, 'Studies in the Psychology of Sex, Volume 6': 1319, 'The Prose Writings of Heinrich Heine': 388, 'Une Vie, a Piece of String and Other Stories': 371, 'The Fortunate Mistress (Parts 1 and 2)': 485, 'Essays of Michel de Montaigne — Complete': 1532, 'Jurgen: A Comedy of Justice': 289, 'Pamela, or Virtue Rewarded': 588, 'Poems & Ballads (Second Series)': 234, "Casanova's Homecoming": 163, 'Sons and Lovers': 584, 'The Delights of Wisdom Pertaining to Conjugial Love': 850, 'The History of the Decline and Fall of the Roman Empire': 96, 'Ulysses': 865, 'The Chinese Classics: with a translation, critical and exegetical notes, prolegomena and copious indexes': 1, 'The Jungle': 503, 'Susan Lenox: Her Fall and Rise': 939, 'The Awakening, and Selected Short Stories': 227, 'Studies in the Psychology of Sex, Volume 1': 783, 'The Robbers': 187, 'Napoleon the Little': 270, "A Mummer's Tale": 130, 'The Advancement of Learning': 449, 'The Kama Sutra of Vatsyayana': 320, 'The Call of the Wild': 175, 'The Rainbow': 736, 'Richard II': 111, 'The Shewing-up of Blanco Posnet': 161, 'Les Misérables': 1664, 'The Dramas of Victor Hugo: Mary Tudor, Marion de Lorme, Esmeralda': 305, 'Studies in the Psychology of Sex, Volume 5': 612, 'First Footsteps in East Africa': 652, 'The Works of Henry Fielding, vol. 12': 249, 'The History of the Devil, As Well Ancient as Modern: In Two Parts': 432, 'The Adventures of Tom Sawyer, Complete': 276, 'Tartuffe; Or, The Hypocrite': 84, 'Sinister Street, vol. 2': 575, 'The Birds': 85, "Gulliver's Travels into Several Remote Nations of the World": 1, "A Mummer's Wife": 494, 'The History of Don Quixote, Volume 1, Complete': 583, 'Leaves of Grass': 649, 'Family Limitation': 41, 'The Writings of Thomas Paine — Volume 4 (1794-1796): The Age of Reason': 340, 'A Sentimental Journey Through France and Italy': 142, 'Sinister Street, vol. 1': 1, "Uncle Tom's Cabin": 519, 'The Golden Asse': 386, 'A Tale of a Tub': 207, 'The Bickerstaff-Partridge Papers': 64, 'An Essay Concerning Humane Understanding, Volume 1': 688, 'A System of Logic, Ratiocinative and Inductive': 1485, 'Three Weeks': 215, 'Paradise Lost': 496, 'The Analects of Confucius (from the Chinese Classics)': 157, 'Dubliners': 274, 'In Praise of Folly': 147, 'Tales and Novels of J. de La Fontaine — Complete': 586, 'Religio Medici, Hydriotaphia, and the Letter to a Friend': 295, 'Dante. An essay. To which is added a translation of De Monarchia.': 393, 'Jude the Obscure': 358, 'Disputation of Doctor Martin Luther on the Power and Efficacy of Indulgences': 51, 'On the Origin of Species By Means of Natural Selection': 888, 'Poems & Ballads (First Series)': 441, 'The Backwash of War': 140, 'The Scarlet Letter': 360, 'Poems and Ballads (Third Series)': 187, 'Esther Waters': 493, 'The Prose Works of Jonathan Swift, D.D. — Volume 06': 460, 'Areopagitica': 88, 'Salammbo': 661, 'The Communist Manifesto': 92, 'Madame Bovary': 474, 'The Memoirs of Jacques Casanova de Seingalt, 1725-1798. Complete': 1614, 'Adam Bede': 563, 'The Commercial Restraints of Ireland': 430, 'Studies in the Psychology of Sex, Volume 4': 611, 'The Kreutzer Sonata and Other Stories': 242, 'The Clouds': 80, 'Faust [part 1]. Translated Into English in the Original M ...

# %%
# Write out the results

# Specify a filename for the results
output_filename = "small_corpus_mdw.csv"

lol2file(output_table, output_filename)
# Out:
# Wrote the file small_corpus_mdw.csv

# %%
target = 'maria'

for f in files:
    words = file2words(f)
    if words.count(target) > 0:
        print(get_shortname(f), words.count(target))
# Out:
# A Sentimental Journey Through France and Italy.txt 17
# The Decameron, Volume I.txt 3
# Corinne; Or, Italy. Volume 1 (of 2).txt 2
# Ulysses.txt 9
# Studies in the Psychology of Sex, Volume 6.txt 6
# Studies in the Psychology of Sex, Volume 3.txt 2
# The Prince.txt 1
# Casanova's Homecoming.txt 3
# The History of Don Quixote, Volume 2, Complete.txt 1
# Les Misérables.txt 3
# The Prose Writings of Heinrich Heine.txt 27
# Une Vie, a Piece of String and Other Stories.txt 1
# The Decameron, Volume II.txt 10
# Uncle Tom's Cabin.txt 1
# The History of Don Quixote, Volume 1, Complete.txt 8
# Voltaire's Philosophical Dictionary.txt 1
# Essays of Michel de Montaigne — Complete.txt 1
# The Rainbow.txt 6
# Dubliners.txt 40
# The Memoirs of Jacques Casanova de Seingalt, 1725-1798. Complete.txt 21
# The Child of Pleasure.txt 129
# Notre-Dame de Paris.txt 3
# The Complete Poetical Works of Percy Bysshe Shelley — Volume 3.txt 1
# The Complete Poetical Works of Percy Bysshe Shelley — Volume 1.txt 2
# Dante. An essay. To which is added a translation of De Monarchia..txt 4
# The Jungle.txt 1
# The Robbers.txt 1
# The Poetical Works of Elizabeth Barrett Browning, Volume 4.txt 1
